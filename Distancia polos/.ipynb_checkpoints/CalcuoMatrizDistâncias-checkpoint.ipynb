# %%
import pandas as pd
import geopandas
from geobr import read_municipal_seat
import geobr

# %%
#Carregando as bases de dados
polos_municipios_df = pd.read_csv('regioes_imediatas.csv')
polos_saude_df = pd.read_csv('polos_AC_REGIC2018.csv')

# %%
imedreg = geobr.read_immediate_region

# %%
## Importando de geobr as localizações municipais
sedes_municipais = read_municipal_seat(year=2010)
sedes_municipais.rename(columns={'code_muni':'CD_GEOCODI'}, inplace=True)

# %%
## Criando colunas independentes para latitude e longitude
sedes_municipais['X']=sedes_municipais.apply(lambda x:x.geometry.centroid.x, axis=1)
sedes_municipais['Y']=sedes_municipais.apply(lambda x:x.geometry.centroid.y, axis=1)

# %%
## Filtrando colunas que vamos precisar
sedes_municipais = sedes_municipais[['CD_GEOCODI','X','Y']].copy()

# %%
## Unindo o dataframes de municipios polo com o de coordenadas dos município
polos_municipios_df = pd.merge(polos_municipios_df,sedes_municipais, how = 'inner')
##OBS: por conta do parâmetro how="inner", linhas com da coluna CD_GEOCODI que não aparecerem nas duas tabelas serão excluídas
##Como a nova tabela de polos municipais possui 441 linhas, nenhum polo foi excluído

# %%
## Criando dataframe vazio com as linhas e colunas necessárias
df_distancias = pd.DataFrame(index = polos_municipios_df.nome_mun, 
                             columns = polos_saude_df.Municipio)

# %%
##LEMBRE-SE: nas tabelas, “x” = long e “y” = lat
##Função para medir distâncias pela biblioteca GEOPY
import geopy.distance

def calc_dist(lat1, long1, lat2, long2):
  coords_1 = (lat1, long1)  
  coords_2 = (lat2, long2)  
  return (geopy.distance.distance(coords_1, coords_2).km)  ##retorna a distância em quilômetros


####EXEMPLO DE USO

##Coordenadas do ICEX
x1 = -19.8701472
y1 = -43.9628217
##Cordenadas do Mineirão
x2 = -19.8673081
y2 = -43.9722844

calc_dist(x1, y1, x2, y2)
# Out:
# 1.0397049356005224

# %%
### PREENCHENDO O NOVO DATAFRAME
### Percorre as linhas e as colunas de "df_distancias" preenchendo os valores de acordo com as coordenadas das tabelas originais

for index, row in df_distancias.iterrows():

  index_mun_origin = polos_municipios_df.loc[polos_municipios_df["nome_mun"] == index].index[0]  ##indice do municipio na tabela original
  x_mun = polos_municipios_df.loc[index_mun_origin, "X"]
  y_mun = polos_municipios_df.loc[index_mun_origin, "Y"]

  for cidade in row.index:
 
    index_sau_origin = polos_saude_df.loc[polos_saude_df["Municipio"] == cidade].index[0] ##indice da unidade de saude na tabela original
    x_sau = polos_saude_df.loc[index_sau_origin, "X"]
    y_sau = polos_saude_df.loc[index_sau_origin, "Y"]

    df_distancias.loc[index, cidade] = calc_dist(y_mun, x_mun, y_sau, x_sau) ##LEMBRE-SE: nas tabelas, “x” = long e “y” = lat

df_distancias
#PODE DEMORAR UM POUCO
# Out:
# Municipio             ARIQUEMES   CACOAL PORTO VELHO  VILHENA CRUZEIRO DO SUL  \
# nome_mun
# Porto Velho             153.823  393.765      8.5897  596.562         981.532
# Ariquemes              0.391731  241.853     158.831  444.821         1089.23
# Jaru                    84.2152  157.422      242.61  360.404          1162.3
# Ji-Paraná               160.394  81.6075      318.12  284.497         1231.39
# Cacoal                  242.137  0.91592     400.174  202.493         1301.66
# ...                         ...      ...         ...      ...             ...
# Palmeiras de Goiás      1611.14  1378.79     1758.59  1187.85         2671.29
# Porangatu               1563.31  1355.93     1693.15  1194.13         2651.55
# Luziânia                1778.44  1552.79     1920.45  1369.15          2852.1
# Águas Lindas de Goiás   1725.21  1501.92     1865.57  1321.17         2802.32
# Flores de Goiás         1810.28  1597.97     1942.64  1429.01         2896.82
#
# Municipio             RIO BRANCO   MANAUS BOA VISTA ALTAMIRA    BELEM  ...  \
# nome_mun                                                               ...
# Porto Velho              456.842  751.954   1328.68  1426.12   1880.9  ...
# Ariquemes                523.866  819.416   1431.76  1407.72  1859.82  ...
# Jaru                     586.669  851.467   1479.54  1387.94  1836.89  ...
# Ji-Paraná                649.995  882.454   1521.87  1369.95     1815  ...
# Cacoal                   715.018  930.896   1578.67   1366.2  1805.71  ...
# ...                          ...      ...       ...      ...      ...  ...
# Palmeiras de Goiás       2078.11  1872.78   2471.64  1525.09   1705.1  ...
# Porangatu                2069.89  1652.72   2203.59  1181.17  1327.58  ...
# Luziânia                 2260.71  1962.81   2531.88  1516.94  1638.43  ...
# Águas Lindas de Goiás    2211.98  1896.94   2464.54  1451.32   1579.9  ...
# Flores de Goiás          2312.06  1896.87    2430.7  1366.78  1446.17  ...
#
# Municipio             TANGARA DA SERRA ANAPOLIS APARECIDA DE GOIANIA    CERES  \
# nome_mun
# Porto Velho                    946.917   1818.6              1815.66  1708.92
# Ariquemes                      797.065  1682.43                 1677  1576.11
# Jaru                           712.706  1602.01              1595.65   1497.1
# Ji-Paraná                      636.476  1528.47              1521.36  1424.75
# Cacoal                          555.14  1453.55              1445.09  1351.91
# ...                                ...      ...                  ...      ...
# Palmeiras de Goiás             846.163  115.882              72.2929   169.08
# Porangatu                      910.406  319.955              374.206  212.524
# Luziânia                       1038.93  107.317              151.095  205.342
# Águas Lindas de Goiás          996.774  97.2787              158.009  149.282
# Flores de Goiás                1125.62  292.078              352.908   291.28
#
# Municipio              GOIANIA ITUMBIARA MINEIROS RIO VERDE  \
# nome_mun
# Porto Velho             1807.3   1906.31  1562.02   1717.87
# Ariquemes              1669.17   1762.46  1414.68   1572.94
# Jaru                   1588.01   1679.35   1330.7   1489.54
# Ji-Paraná              1513.88   1603.73  1254.57   1413.75
# Cacoal                 1437.91   1524.73  1174.08   1334.33
# ...                        ...       ...      ...       ...
# Palmeiras de Goiás     72.4226   193.574  292.115    150.65
# Porangatu              358.484   550.825  584.875   516.372
# Luziânia               146.523   274.118  510.651   356.866
# Águas Lindas de Goiás  147.297   312.924  498.397   360.045
# Flores de Goiás        342.267   496.668  682.945   553.987
#
# Municipio             SANTA HELENA DE GOIAS BRASILIA
# nome_mun
# Porto Velho                         1747.09  1896.86
# Ariquemes                           1602.62  1764.87
# Jaru                                1519.36  1686.07
# Ji-Paraná                           1443.65  1613.87
# Cacoal                              1364.44  1541.15
# ...                                     ...      ...
# Palmeiras de Goiás                  132.487  243.249
# Porangatu                           508.121  291.463
# Luziânia                            329.697   52.722
# Águas Lindas de Goiás               337.056  40.5532
# Flores de Goiás                     531.829  174.349
#
# [442 rows x 316 columns]

# %%
#Salvando em CSV 
df_distancias.to_csv("matriz_distâncias.csv")
